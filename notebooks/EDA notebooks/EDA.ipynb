# %%
import numpy as np
import pandas as pd

# %%
#ben_cost=pd.read_csv('../data/Benefits_Cost_Sharing_PUF.csv',low_memory=False, encoding ='latin1')
#rules=pd.read_csv('../data/Business_Rules_PUF.csv',low_memory=False, encoding ='latin1')
#network=pd.read_csv('../data/Network_PUF.csv',low_memory=False, encoding ='latin1')
#attr=pd.read_csv('../data/Plan_Attributes_PUF.csv',low_memory=False, encoding ='latin1')
#rate=pd.read_csv('../data/Rate_PUF.csv',low_memory=False, encoding ='latin1')
area=pd.read_csv('../data/Service_Area_PUF.csv',low_memory=False, encoding ='latin1')
area
# Out:
#        BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0              2020        TX     71837       HIOS  2019-09-12 03:20:22
# 1              2020        TX     71837       HIOS  2019-09-12 03:20:22
# 2              2020        TX     71837       HIOS  2019-09-12 03:20:22
# 3              2020        TX     71837       HIOS  2019-09-12 03:20:22
# 4              2020        TX     90453       HIOS  2019-06-13 03:20:23
# 5              2020        TX     91476       HIOS  2019-08-14 03:20:21
# 6              2020        TX     92388       HIOS  2019-05-18 03:20:33
# 7              2020        TX     98899       HIOS  2019-05-16 03:20:18
# 8              2020        WI     14630       HIOS  2019-08-08 03:20:20
# 9              2020        WI     14630       HIOS  2019-08-08 03:20:20
# 10             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 11             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 12             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 13             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 14             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 15             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 16             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 17             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 18             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 19             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 20             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 21             2020        WI     14630       HIOS  2019-08-08 03:20:20
# 22             2020        WI     16837       HIOS  2019-08-20 03:21:07
# 23             2020        WI     20173       HIOS  2019-08-21 03:21:10
# 24             2020        WI     20173       HIOS  2019-08-21 03:21:10
# 25             2020        WI     20173       HIOS  2019-08-21 03:21:10
# 26             2020        WI     20173       HIOS  2019-08-21 03:21:10
# 27             2020        WI     20173       HIOS  2019-08-21 03:21:10
# 28             2020        WI     34210       HIOS  2019-08-15 11:54:37
# 29             2020        WI     37833       HIOS  2019-07-31 03:20:24
# ...             ...       ...       ...        ...                  ...
# 11278          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11279          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11280          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11281          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11282          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11283          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11284          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11285          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11286          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11287          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11288          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11289          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11290          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11291          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11292          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11293          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11294          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11295          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11296          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11297          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11298          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11299          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11300          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11301          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11302          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11303          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11304          2020        WV     50328      SERFF  2019-08-16 20:17:10
# 11305          2020        WV     53843      SERFF  2019-08-21 20:17:17
# 11306          2020        WV     76526      SERFF  2019-08-16 20:17:10
# 11307          2020        WV     94562      SERFF  2019-08-16 20:17:10
#
#       ServiceAreaId                   ServiceAreaName CoverEntireState  \
# 0            TXS001                            Travis               No
# 1            TXS001                            Travis               No
# 2            TXS001                            Travis               No
# 3            TXS001                            Travis               No
# 4            TXS001                             Texas              Yes
# 5            TXS001                             Texas              Yes
# 6            TXS001  MetLife Preferred Dental Program              Yes
# 7            TXS001                             Texas              Yes
# 8            WIS001                         Milwaukee               No
# 9            WIS001                            Racine               No
# 10           WIS001                           Kenosha               No
# 11           WIS001                          Waukesha               No
# 12           WIS001                        Washington               No
# 13           WIS001                           Ozaukee               No
# 14           WIS001                           Calumet               No
# 15           WIS001                         Outagamie               No
# 16           WIS001                            Oconto               No
# 17           WIS001                         Winnebago               No
# 18           WIS001                             Brown               No
# 19           WIS001                              Door               No
# 20           WIS001                          Kewaunee               No
# 21           WIS001                         Manitowoc               No
# 22           WIS001                      Dentegra PPO              Yes
# 23           WIS001   HealthPartners Atlas Individual               No
# 24           WIS001   HealthPartners Atlas Individual               No
# 25           WIS001   HealthPartners Atlas Individual               No
# 26           WIS001   HealthPartners Atlas Individual               No
# 27           WIS001   HealthPartners Atlas Individual               No
# 28           WIS001                         Wisconsin              Yes
# 29           WIS001                      Quartz Prime               No
# ...             ...                               ...              ...
# 11278        WVS001                     West Virginia               No
# 11279        WVS001                     West Virginia               No
# 11280        WVS001                     West Virginia               No
# 11281        WVS001                     West Virginia               No
# 11282        WVS001                     West Virginia               No
# 11283        WVS001                     West Virginia               No
# 11284        WVS001                     West Virginia               No
# 11285        WVS001                     West Virginia               No
# 11286        WVS001                     West Virginia               No
# 11287        WVS001                     West Virginia               No
# 11288        WVS001                     West Virginia               No
# 11289        WVS001                     West Virginia               No
# 11290        WVS001                     West Virginia               No
# 11291        WVS001                     West Virginia               No
# 11292        WVS001                     West Virginia               No
# 11293        WVS001                     West Virginia               No
# 11294        WVS001                     West Virginia               No
# 11295        WVS001                     West Virginia               No
# 11296        WVS001                     West Virginia               No
# 11297        WVS001                     West Virginia               No
# 11298        WVS001                     West Virginia               No
# 11299        WVS001                     West Virginia               No
# 11300        WVS001                     West Virginia               No
# 11301        WVS001                     West Virginia               No
# 11302        WVS001                     West Virginia               No
# 11303        WVS001                     West Virginia               No
# 11304        WVS001                     West Virginia               No
# 11305        WVS001                      DENTEGRA PPO              Yes
# 11306        WVS001                               PPO              Yes
# 11307        WVS001  MetLife Preferred Dental Program              Yes
#
#         County PartialCounty ZipCodes PartialCountyJustification  \
# 0      48149.0            No      NaN                        NaN
# 1      48055.0            No      NaN                        NaN
# 2      48053.0            No      NaN                        NaN
# 3      48021.0            No      NaN                        NaN
# 4          NaN           NaN      NaN                        NaN
# 5          NaN           NaN      NaN                        NaN
# 6          NaN           NaN      NaN                        NaN
# 7          NaN           NaN      NaN                        NaN
# 8      55079.0            No      NaN                        NaN
# 9      55101.0            No      NaN                        NaN
# 10     55059.0            No      NaN                        NaN
# 11     55133.0            No      NaN                        NaN
# 12     55131.0            No      NaN                        NaN
# 13     55089.0            No      NaN                        NaN
# 14     55015.0            No      NaN                        NaN
# 15     55087.0            No      NaN                        NaN
# 16     55083.0            No      NaN                        NaN
# 17     55139.0            No      NaN                        NaN
# 18     55009.0            No      NaN                        NaN
# 19     55029.0            No      NaN                        NaN
# 20     55061.0            No      NaN                        NaN
# 21     55071.0            No      NaN                        NaN
# 22         NaN           NaN      NaN                        NaN
# 23     55013.0            No      NaN                        NaN
# 24     55031.0            No      NaN                        NaN
# 25     55095.0            No      NaN                        NaN
# 26     55093.0            No      NaN                        NaN
# 27     55109.0            No      NaN                        NaN
# 28         NaN           NaN      NaN                        NaN
# 29     55021.0            No      NaN                        NaN
# ...        ...           ...      ...                        ...
# 11278  54053.0            No      NaN                        NaN
# 11279  54047.0            No      NaN                        NaN
# 11280  54059.0            No      NaN                        NaN
# 11281  54061.0            No      NaN                        NaN
# 11282  54069.0            No      NaN                        NaN
# 11283  54073.0            No      NaN                        NaN
# 11284  54077.0            No      NaN                        NaN
# 11285  54079.0            No      NaN                        NaN
# 11286  54081.0            No      NaN                        NaN
# 11287  54085.0            No      NaN                        NaN
# 11288  54087.0            No      NaN                        NaN
# 11289  54091.0            No      NaN                        NaN
# 11290  54095.0            No      NaN                        NaN
# 11291  54099.0            No      NaN                        NaN
# 11292  54103.0            No      NaN                        NaN
# 11293  54105.0            No      NaN                        NaN
# 11294  54107.0            No      NaN                        NaN
# 11295  54109.0            No      NaN                        NaN
# 11296  54007.0            No      NaN                        NaN
# 11297  54023.0            No      NaN                        NaN
# 11298  54041.0            No      NaN                        NaN
# 11299  54067.0            No      NaN                        NaN
# 11300  54075.0            No      NaN                        NaN
# 11301  54083.0            No      NaN                        NaN
# 11302  54089.0            No      NaN                        NaN
# 11303  54093.0            No      NaN                        NaN
# 11304  54097.0            No      NaN                        NaN
# 11305      NaN           NaN      NaN                        NaN
# 11306      NaN           NaN      NaN                        NaN
# 11307      NaN           NaN      NaN                        NaN
#
#            MarketCoverage DentalOnlyPlan
# 0              Individual             No
# 1              Individual             No
# 2              Individual             No
# 3              Individual             No
# 4      SHOP (Small Group)            Yes
# 5              Individual            Yes
# 6      SHOP (Small Group)            Yes
# 7      SHOP (Small Group)            Yes
# 8              Individual             No
# 9              Individual             No
# 10             Individual             No
# 11             Individual             No
# 12             Individual             No
# 13             Individual             No
# 14             Individual             No
# 15             Individual             No
# 16             Individual             No
# 17             Individual             No
# 18             Individual             No
# 19             Individual             No
# 20             Individual             No
# 21             Individual             No
# 22             Individual            Yes
# 23             Individual             No
# 24             Individual             No
# 25             Individual             No
# 26             Individual             No
# 27             Individual             No
# 28             Individual            Yes
# 29             Individual             No
# ...                   ...            ...
# 11278          Individual             No
# 11279          Individual             No
# 11280          Individual             No
# 11281          Individual             No
# 11282          Individual             No
# 11283          Individual             No
# 11284          Individual             No
# 11285          Individual             No
# 11286          Individual             No
# 11287          Individual             No
# 11288          Individual             No
# 11289          Individual             No
# 11290          Individual             No
# 11291          Individual             No
# 11292          Individual             No
# 11293          Individual             No
# 11294          Individual             No
# 11295          Individual             No
# 11296          Individual             No
# 11297          Individual             No
# 11298          Individual             No
# 11299          Individual             No
# 11300          Individual             No
# 11301          Individual             No
# 11302          Individual             No
# 11303          Individual             No
# 11304          Individual             No
# 11305          Individual            Yes
# 11306          Individual            Yes
# 11307  SHOP (Small Group)            Yes
#
# [11308 rows x 14 columns]

# %%
#area.head()

'''
From qaulity - Global ratngs for plans in VA. Mean =3.600000, min=	2 max = 5
'''
area.groupby('StateCode')['IssuerId'].count()
# Out:
# StateCode
# AK      13
# AL      57
# AR      27
# AZ      70
# DE       5
# FL     409
# GA     706
# HI       5
# IA     247
# IL     495
# IN     276
# KS     262
# KY     267
# LA      87
# ME      40
# MI    1363
# MO     588
# MS     105
# MT     138
# NC     259
# ND     108
# NE     193
# NH      17
# NJ      96
# NM      39
# OH     520
# OK     294
# OR     135
# PA     634
# SC     136
# SD      11
# TN     339
# TX    1721
# UT      63
# VA    1078
# WI     452
# WV      48
# WY       5
# Name: IssuerId, dtype: int64

# %%
#area['DentalOnlyPlan'].unique()
#area.groupby('DentalOnlyPlan').count()

#this gets rid of the Dental Only Plans leaving medical insurance plans then drops the column as superfilous
area=area[area.DentalOnlyPlan != 'Yes']
area.drop('DentalOnlyPlan', axis=1, inplace=True)

area=area.drop(['BusinessYear','SourceName', 'ImportDate'], axis = 1)
area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5643 entries, 0 to 11304
# Data columns (total 10 columns):
# StateCode                     5643 non-null object
# IssuerId                      5643 non-null int64
# ServiceAreaId                 5643 non-null object
# ServiceAreaName               5643 non-null object
# CoverEntireState              5643 non-null object
# County                        5598 non-null float64
# PartialCounty                 5598 non-null object
# ZipCodes                      53 non-null object
# PartialCountyJustification    53 non-null object
# MarketCoverage                5643 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 484.9+ KB

# %%
zipcodes=area[area.ZipCodes.isnull() == False]
zipcodes
zipcodes.groupby('StateCode').count()
# Out:
#            BusinessYear  IssuerId  SourceName  ImportDate  ServiceAreaId  \
# StateCode
# MI                   15        15          15          15             15
# NE                    1         1           1           1              1
# OR                    9         9           9           9              9
# PA                    3         3           3           3              3
# TX                    1         1           1           1              1
# VA                   36        36          36          36             36
# WI                    1         1           1           1              1
#
#            ServiceAreaName  CoverEntireState  County  PartialCounty  ZipCodes  \
# StateCode
# MI                      15                15      15             15        15
# NE                       1                 1       1              1         1
# OR                       9                 9       9              9         9
# PA                       3                 3       3              3         3
# TX                       1                 1       1              1         1
# VA                      36                36      36             36        36
# WI                       1                 1       1              1         1
#
#            PartialCountyJustification  MarketCoverage  DentalOnlyPlan
# StateCode
# MI                                 15              15              15
# NE                                  1               1               1
# OR                                  9               9               9
# PA                                  3               3               3
# TX                                  1               1               1
# VA                                 36              36              36
# WI                                  1               1               1

# %% [markdown]
# #area.groupby('StateCode').count()
#
# uniques={}
# for col in area.columns:
#     uniques[col]=area[col].unique()
# uniques

# %%
area_FL=area[area.StateCode == 'FL'].copy()
'''
EDA shows FL does not have  plans based on 'PartialCounty', ''ZipCodes', or
PartialCountyJustification' so they are being dropped

'''

area_FL=area_FL.drop(['PartialCounty', 'ZipCodes', 'PartialCountyJustification'], axis = 1)

# %%
area_FL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165 entries, 215 to 576
# Data columns (total 7 columns):
# StateCode           165 non-null object
# IssuerId            165 non-null int64
# ServiceAreaId       165 non-null object
# ServiceAreaName     165 non-null object
# CoverEntireState    165 non-null object
# County              164 non-null float64
# MarketCoverage      165 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 10.3+ KB

# %%
area_FL.head()
# Out:
#     StateCode  IssuerId ServiceAreaId             ServiceAreaName  \
# 215        FL     12379        FLS001  Bright Health Service Area
# 216        FL     12379        FLS001  Bright Health Service Area
# 217        FL     12379        FLS001  Bright Health Service Area
# 218        FL     12379        FLS001  Bright Health Service Area
# 219        FL     12379        FLS001  Bright Health Service Area
#
#     CoverEntireState   County MarketCoverage
# 215               No  12095.0     Individual
# 216               No  12117.0     Individual
# 217               No  12097.0     Individual
# 218               No  12069.0     Individual
# 219               No  12127.0     Individual

# %%
uniques={} 
for col in area_FL.columns: 
    uniques[col]=area_VA[col].unique()
uniques
# Out:
# ------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-8-ef3b4c838bb6> in <module>
#       1 uniques={}
#       2 for col in area_FL.columns:
# ----> 3     uniques[col]=area_VA[col].unique()
#       4 uniques
#
# NameError: name 'area_VA' is not defined

# %%
in_state= area_FL[area_FL.CoverEntireState== 'Yes']
in_state

# %%
area_FL.groupby('IssuerId').count()

# %%
def geo(row):
    if row['A'] == row['B']:
        val = 0
    elif row['A'] > row['B']:
        val = 1
    else:
        val = -1
    return val

# %%
area_FL['Geo']=

# %%
fips= pd.read_csv('../data/zipcodes-county-fips-crosswalk/ZIP-COUNTY-FIPS_2017-06.csv',  dtype='str')
fips.head()
